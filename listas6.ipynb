# %%
n = int(input("cuantas materias tienes asignadas: "))
lista_materias = []

for i in range(0,n):
    asignaturas = input("Nombre de asignaturas: ")
    lista_materias.append(asignaturas)
    #print(lista_materias)
    
    for materia in lista_materias: # itera contenido de lista
        # que nota tienes por asignatura, iteramos la lista de materias y eliminamos las materias pasadas.
        nota = float(input("Que nota tienes en "+ lista_materias[-1] + "? "))
        print()
        if nota >= 60:
            lista_materias.remove(materia)
        # si es menor de 60 lo almacena
        break
print("Debes retomar las siguientes materias: ", lista_materias)
# Out:
# cuantas materias tienes asignadas: 4
# Nombre de asignaturas: historia
# Que nota tienes en historia? 100
#
# Nombre de asignaturas: literatura
# Que nota tienes en literatura? 50
#
# Nombre de asignaturas: arte
# Que nota tienes en arte? 20
#
# Nombre de asignaturas: espanol
# Que nota tienes en espanol? 10
#
# Debes retomar las siguientes materias:  ['literatura', 'arte', 'espanol']

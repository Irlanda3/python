# %%
lista = ["Matematicas", "Fisica", "Quimica", "Historia","Lengua"]
print(lista)
# Out:
# ['Matematicas', 'Fisica', 'Quimica', 'Historia', 'Lengua']

# %%
#Yo estudio <asignatura>, donde <asignatura>
for materias in lista:
    print("Yo estudio", materias, "donde", materias)
# Out:
# Yo estudio Matematicas donde Matematicas
# Yo estudio Fisica donde Fisica
# Yo estudio Quimica donde Quimica
# Yo estudio Historia donde Historia
# Yo estudio Lengua donde Lengua

# %%
#En <asignatura> has sacado <nota> 
    usuario = input("Teclea tu calificacion de asignatura");
    print("En", materias, "has sacado", int(usuario))
# Out:
# Teclea tu calificacion de asignatura90
# En Lengua has sacado 90

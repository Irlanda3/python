# %%
lista = ["Matematicas", "Fisica", "Quimica", "Historia","Lengua"]
print(lista)
# Out:
# ['Matematicas', 'Fisica', 'Quimica', 'Historia', 'Lengua']

# %%
#Yo estudio <asignatura>
for materias in lista:
    print("Yo estudio", materias);
    usuario = input("Teclea tu calificacion de asignatura", materias);
    #print("En", materias, "has sacado", int(usuario))
# Out:
# Yo estudio Matematicas
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c49fe17bd736> in <module>
#       2 for materias in lista:
#       3     print("Yo estudio", materias);
# ----> 4     usuario = input("Teclea tu calificacion de asignatura", materias);
#       5     #print("En", materias, "has sacado", int(usuario))
#
# TypeError: raw_input() takes from 1 to 2 positional arguments but 3 were given

# %%
lista = ["Matematicas", "Fisica", "Quimica", "Historia","Lengua"]
print(lista)
# Out:
# ['Matematicas', 'Fisica', 'Quimica', 'Historia', 'Lengua']

# %%
# Yo estudio <asignatura>
for materias in lista:
    print("Yo estudio", materias);
    usuario = input("Teclea tu calificacion de la asignatura" + " " + materias + ": ")
    print();
# Out:
# Yo estudio Matematicas
# Teclea tu calificacion de la asignatura Matematicas: 100
#
# Yo estudio Fisica
# Teclea tu calificacion de la asignatura Fisica: 6515
#
# Yo estudio Quimica
# Teclea tu calificacion de la asignatura Quimica: 55
#
# Yo estudio Historia
# Teclea tu calificacion de la asignatura Historia: 515
#
# Yo estudio Lengua
# Teclea tu calificacion de la asignatura Lengua: 1515
